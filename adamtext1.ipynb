# %% [markdown]
# 第一個jupyter程式測試

# %%
a="宗"
X="承"
a+X
# Out:
# '宗承'

# %%
aa=2
xx=3
aa+xx
# Out:
# 5

# %%
第二個jupyter程式特測試ˇ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5ec0b33a1955> in <module>()
# ----> 1 第二個jupyter程式特測試ˇ
#
# NameError: name '第二個jupyter程式特測試ˇ' is not defined

# %%
Y="程式設計"
an="商用"
a+X+an+Y
# Out:
# '宗承商用程式設計'

# %% [markdown]
# 3行寫出 尋找指定網頁的原始碼

# %%
import requests
c=requests.get("http://www.yahoo.com.tw")
print(c.text)
# Out:
# <!DOCTYPE html>
# <html id="Stencil" lang="zh-Hant-TW" class="StencilRoot  my3columns  l-out Pos-r https fp fp-default ltr desktop Desktop bkt900">
# <head>
#
# ...
